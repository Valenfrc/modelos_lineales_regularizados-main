# %% [markdown]
# # Explore here

# %%
import pandas as pd

df=pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv')
df
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB

# %%
df.drop_duplicates()
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB

# %%
df.describe(include='O')
# Out:
#        COUNTY_NAME STATE_NAME
# count         3140       3140
# unique        1841         51
# top     Washington      Texas
# freq            31        254

# %%
#empezare a analizar las variables categoricas

import matplotlib.pyplot as plt
import seaborn as sns

c=df.groupby('COUNTY_NAME').size().reset_index()
s=df.groupby('STATE_NAME').size().reset_index()
print('c','s')
# Out:
# c s

# %%
import matplotlib.pyplot as plt
import pandas as pd 

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10)) 

axes[0].bar(c.COUNTY_NAME, c.iloc[:, 0])
axes[0].set_title("COUNTY_NAME")

axes[1].bar(s.STATE_NAME, s.iloc[:, 0])
axes[1].set_title("STATE_NAME")

# Reduce font size and adjust spacing
axes[0].tick_params(axis='x', rotation=90, labelsize=8)  # Smaller font
axes[1].tick_params(axis='x', rotation=90, labelsize=8)  # Smaller font

plt.tight_layout()
plt.show()

# %%
print(c.head())
# Out:
#   COUNTY_NAME  0
# 0   Abbeville  1
# 1      Acadia  1
# 2    Accomack  1
# 3         Ada  1
# 4       Adair  4

# %%
import plotly.express as px

fig = px.histogram(c, x='COUNTY_NAME')
fig.show()

# %%
print("\nÍndice (nombres de las filas):")
print(df.index.tolist())
# Out:
# Índice (nombres de las filas):
# ...

# %%
print("\nTipos de datos de las columnas:")
print(df.dtypes)
# Out:
# Tipos de datos de las columnas:
# fips                        int64
# TOT_POP                     int64
# 0-9                         int64
# 0-9 y/o % of total pop    float64
# 19-Oct                      int64
#                            ...
# CKD_prevalence            float64
# CKD_Lower 95% CI          float64
# CKD_Upper 95% CI          float64
# CKD_number                  int64
# Urban_rural_code            int64
# Length: 108, dtype: object

# %%
#Ahora analizaremos las variables numericas
import seaborn as sns
fig, axes = plt.subplots(12, 2, figsize=(15, 30))

variables_numericas = ['fips','TOT_POP','0-9''0-9 y/o % of total pop','19-Oct','CKD_prevalence','CKD_Lower 95% CI','CKD_Upper 95% CI','CKD_number','Urban_rural_code']

for i, variable in enumerate(variables_numericas):
    # Histograma
    sns.histplot(ax=axes[i, 0], data=df, x=variable, kde=True)  # kde para suavizar la curva
    axes[i, 0].set_title(f"Histograma de {variable}")
    axes[i, 0].set_xlabel(variable)
    axes[i, 0].set_ylabel("Frecuencia")

    # Boxplot
    sns.boxplot(ax=axes[i, 1], data=df, x=variable)
    axes[i, 1].set_title(f"Boxplot de {variable}")
    axes[i, 1].set_xlabel(variable)
    axes[i, 1].set_ylabel("Valor")  # Ajusta la etiqueta del eje y

plt.tight_layout()
plt.show()

#el histplot lo estoy usando para enterarme de los datos recurrentes
#el boxplot lo estoy utilizando para los valores atipicos
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 9
#       5 variables_numericas = ['fips','TOT_POP','0-9''0-9 y/o % of total pop','19-Oct','CKD_prevalence','CKD_Lower 95% CI','CKD_Upper 95% CI','CKD_number','Urban_rural_code']
#       7 for i, variable in enumerate(variables_numericas):
#       8     # Histograma
# ----> 9     sns.histplot(ax=axes[i, 0], data=df, x=variable, kde=True)  # kde para suavizar la curva
#      10     axes[i, 0].set_title(f"Histograma de {variable}")
#      11     axes[i, 0].set_xlabel(variable)
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


df.columns = df.columns.str.replace('[^A-Za-z0-9_]+', '_', regex=True) #remplaza caracteres especiales por guion bajo
df.columns = df.columns.str.replace(' ', '_', regex=True) #remplaza espacios por guion bajo

fig, axes = plt.subplots(10, 2, figsize=(15, 30)) #cambiar el numero de filas a 10.

variables_numericas = ['fips', 'TOT_POP', '0_9', '0_9_y_o_percent_of_total_pop', '19_Oct', 'CKD_prevalence', 'CKD_Lower_95_CI', 'CKD_Upper_95_CI', 'CKD_number', 'Urban_rural_code']

for i, variable in enumerate(variables_numericas):
    
    sns.histplot(ax=axes[i, 0], data=df, x=variable, kde=True)  # kde para suavizar la curva
    axes[i, 0].set_title(f"Histograma de {variable}")
    axes[i, 0].set_xlabel(variable)
    axes[i, 0].set_ylabel("Frecuencia")

    
    sns.boxplot(ax=axes[i, 1], data=df, x=variable)
    axes[i, 1].set_title(f"Boxplot de {variable}")
    axes[i, 1].set_xlabel(variable)
    axes[i, 1].set_ylabel("Valor")  # Ajusta la etiqueta del eje y

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 15
#      11 variables_numericas = ['fips', 'TOT_POP', '0_9', '0_9_y_o_percent_of_total_pop', '19_Oct', 'CKD_prevalence', 'CKD_Lower_95_CI', 'CKD_Upper_95_CI', 'CKD_number', 'Urban_rural_code']
#      13 for i, variable in enumerate(variables_numericas):
# ---> 15     sns.histplot(ax=axes[i, 0], data=df, x=variable, kde=True)  # kde para suavizar la curva
#      16     axes[i, 0].set_title(f"Histograma de {variable}")
#      17     axes[i, 0].set_xlabel(variable)
#
# ...
